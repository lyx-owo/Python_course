# %% [markdown]
# 請寫一個程式先產生score空串列，再依序使用score.append()涵式依序加入80,70,60的資料。最後印出score串列

# %%
score=[]
print('目前串列內容=',score)
score.append('80')
print('目前串列內容=',score)
score.append('70')
print('目前串列內容=',score)
score.append('60')
print('目前串列內容=',score)
# Out:
# 目前串列內容= []
# 目前串列內容= ['80']
# 目前串列內容= ['80', '70']
# 目前串列內容= ['80', '70', '60']
