# %%
answer = 30
guess =0
while guess != answer:
    guess = int(input("請猜１－１００間的數字　＝　"))
    if guess > answer:
        print("請猜小一點")
    elif guess < answer:
        print("請猜大一點")
    else:
        print("恭喜答對了")
# Out:
# 請猜１－１００間的數字　＝　10
# 請猜大一點
# 請猜１－１００間的數字　＝　80
# 請猜小一點
# 請猜１－１００間的數字　＝　60
# 請猜小一點
# 請猜１－１００間的數字　＝　40
# 請猜小一點
# 請猜１－１００間的數字　＝　20
# 請猜大一點
# 請猜１－１００間的數字　＝　30
# 恭喜答對了
