# %% [markdown]
# 請分別產生下列數列
#
# mylist1= [0, 1, 2, 3, 4, 5]
#
# mylist2= [1, 3, 5, 7, 9]
#
# mylist3= [11, 14, 17, 20]
#
# mylist4= [5, 4, 3, 2, 1]

# %%
mylist1=list(range(6))
print("mylist1=",mylist1)
mylist2=list(range(1,10,2))
print("mylist2=",mylist2)
mylist3=list(range(11,23,3))
print("mylist3=",mylist3)
mylist4=list(range(5,0,-1))
print("mylist4=",mylist4)
# Out:
# mylist1= [0, 1, 2, 3, 4, 5]
# mylist2= [1, 3, 5, 7, 9]
# mylist3= [11, 14, 17, 20]
# mylist4= [5, 4, 3, 2, 1]
